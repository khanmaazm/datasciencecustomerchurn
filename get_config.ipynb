# %%
config = {
  "paths": {
	"raw_data": "/dbfs/FileStore/tables/raw",
	"processed_data": "/dbfs/mnt/dam-churn/processed",
	"external_data": "/dbfs/mnt/dam-churn/external",
    "recieved_data": "/dbfs/mnt/dam-churn/recieved",
	"2018_data": "data/new_data/2018_data",
	"output": "/dbfs/mnt/dam-churn/reports",
	"models_folder": "/dbfs/mnt/dam-churn/models",
	"raw": {
		"coords": "/dbfs/FileStore/tables/raw/coords.xlsx",
		"tenant_history": "/dbfs/FileStore/tables/raw/tenant_history.xlsx",
		"residential_detail": "/dbfs/FileStore/tables/raw/commleasebut_resi_det.xlsx",
		"unitxref": "/dbfs/FileStore/tables/raw/unitxref.xlsx",
		"property": "/dbfs/FileStore/tables/raw/property.xlsx",
		"unit": "/dbfs/FileStore/tables/raw/unit.xlsx",
		"unit_type": "/dbfs/FileStore/tables/raw/unittype.xlsx",
		"commamendments": "/dbfs/FileStore/tables/raw/commamendments.xlsx",
        "coords": "/dbfs/FileStore/tables/raw/coords",
        "service_requests": "/dbfs/FileStore/tables/raw/mm2wo.xlsx"
	},
	"processed": {

	}
  },
  "data_params": {
      		"tenant_history": {
			"functions": {
				"raw": "get_raw_tenant_history_data",
				"processed": "get_processed_tenant_history"
			},
			"suffix": "thist",
			"cols_to_drop": [
				"bautorespond",
				"bfromagent",
				"binactive",
				"dtappointmentend",
				"dtappointmentstart",
				"dtcompleted",
				"dtdue",
				"dtexpired",
				"dtfollowupmissed",
				"dtlastmodified",
				"hroom",
				"hstuacademicterm",
				"hstuguarantor",
				"hstujointseveral",
				"htemplate",
				"htemplatedetail",
				"husermodifiedby",
				"iactivitytype",
				"irating",
				"schanneltype",
				"sfollowuptype",
				"snotes",
				"sphonenum",
				"sresult",
				"ssource",
				"bmtm",
				"huser",
				"trowversion",
				"hagent"
			],
			"fill_nas": {

			},
			"renaming_cols": {
			},
			"column_formats": {
				"character": [
					"sevent"
				],
				"numeric": [
					"crent",
					"cdeposit0",
					"dsqft"
				],
				"id": [
					"htent",
					"hunit"
				]
			}
		},
    	"coords": {
			"functions": {
				"raw": "get_raw_coords_data",
				"processed": None
			},
			"suffix": "coords",
			"cols_to_drop": [
				"country"
			],
			"fill_nas": {
			},
			"renaming_cols": {
				"account_id_new": "acc_id",
				"account_record_type": "record_type",
				"person_account_gender": "gender",
				"person_account_nationality": "nationality",
				"person_account_status": "status",
				"person_account_birthdate": "dob"
			},
			"column_formats": {
				"character": [
					"name"
				],
				"numeric": [
					"latitude",
					"longitude"
				]
			}
		},
      "residential_detail": {
          "functions": {
                  "raw": "get_raw_resi_detail_data",
                  "processed": None
          },
          "suffix": "residet",
          "cols_to_drop": [
              "hmy"
          ],
          "fill_nas": {

          },
          "renaming_cols": {
          },
          "column_formats": {
              "character": [
                  "latemovein_reason",
                  "scode",
                  "pass_issue_place",
                  "nationality",
                  "gender",
                  "individual_categry",
                  "related_tenant",
                  "type"
              ],
              "numeric": [
              ],
              "id": [
                  "hcode"
              ]
          }
      },
      "unitxref": {
          "functions": {
                  "raw": "get_raw_unitxref_data",
                  "processed": None
          },
          "suffix": "unitxref",
          "cols_to_drop": [
              "binactive",
              "dtinactive",
              "hcondocontract",
              "hcopyfrom",
              "hforeigndb",
              "hoption",
              "hproposal",
              "ipersontype",
              "ispastprimaryowner",
              "sextreference",
              "snotes"
          ],
          "fill_nas": {

          },
          "renaming_cols": {
          },
          "column_formats": {
              "character": [
                  "hcommmoveoutreason",
                  "hamendmentinactive",
                  "hmasterunit"
              ],
              "numeric": [
                  "dsqft",
                  "bactive"
              ],
              "id": [
                  "hmy",
                  "hunit",
                  "htenant",
                  "hamendment"
              ]
          }
      },
      "property": {
          "functions": {
                  "raw": "get_raw_prop_data",
                  "processed": None
          },
          "suffix": "prop",
          "cols_to_drop": [

          ],
          "fill_nas": {

          },
          "renaming_cols": {
          },
          "cols_to_keep": [
              "hmy",
              "saddr2"
          ],
          "column_formats": {
              "character": [
                  "saddr2"
              ],
              "numeric": [

              ],
              "id": [
                  "hmy"
              ]
          }
      },
      "unit": {
          "functions": {
                  "raw": "get_raw_unit_data",
                  "processed": None
          },
          "suffix": "unit",
          "cols_to_drop": [
              "srent"

          ],
          "fill_nas": {

          },
          "renaming_cols": {
          },
          "cols_to_keep": [
          ],
          "column_formats": {
              "character": [
              ],
              "numeric": [
                  "dsqft"
              ],
              "id": [
                  "hmy",
                  "hproperty",
                  "hunittype"
              ]
          }
      },
      "unit_type": {
          "functions": {
                  "raw": "get_raw_unit_type_data",
                  "processed": None
          },
          "suffix": "unittype",
          "cols_to_drop": [
              "hproperty"
          ],
          "fill_nas": {

          },
          "renaming_cols": {
          },
          "cols_to_keep": [
          ],
          "column_formats": {
              "character": [
                  "scode",
                  "sdesc"
              ],
              "numeric": [
                  "dsqft"
              ],
              "id": [
                  "hmy"
              ]
          }
      },
      "commamendments": {
          "functions": {
                  "raw": "get_raw_commamendments_data",
                  "processed": None
          },
          "suffix": "amme",
          "cols_to_drop": [
              "bholdunits",
              "dpenalty",
              "dtcontractenddate",
              "dtoccupancy",
              "dtproposalversiondate",
              "dtrentstart",
              "hamendmentcopyfrom",
              "hcopyfrom",
              "hdeal",
              "hforeigndb",
              "hproposalprobability",
              "irisktype",
              "sextreference",
              "sproposalversioncomment",
              "ssubject",
              "bcopycam",
              "bcopymisc",
              "bcopyrecovery",
              "bcopyrent",
              "bcopyretail",
              "bcopyspace",
              "dholdoverpercentage",
              "hoption",
              "hparentamendment",
              "hproposalversiontype",
              "hproposalversionuser",
              "iestimatetype",
              "hproposaloriginalversion",
              "hcommmoveoutreason",
              "dproposalprobability",
              "trowversion",
              "hetllog"
          ],
          "cols_to_keep": [

          ],
          "fill_nas": {

          },
          "renaming_cols": {
          },
          "column_formats": {
              "character": [
                  "sdesc"
              ],
              "numeric": [
                  "dproposalprobability",
                  "dcontractarea",
                  "drent"
              ],
              "id": [
                  "htenant",
                  "hmy"
              ]
          }
      },
      "service_requests": {
          "functions": {
                  "raw": "get_raw_sr_data",
                  "processed": "get_processed_sr_data"
          },
          "suffix": "sr",
          "cols_to_drop": [
            "scode",
            "hvendor",
            "hchgrcd",
            "hcommchgrcd",
            "hcommpayrcd",
            "hcmppayrcd",
            "hasset",
            "hrecwo",
            "hrelwo",
            "htmpl",
            "sauthorized",
            "sfulldesc",
            "dtsched",
            "dtcanc",
            "dtuser1",
            "dtuser2",
            "dtuser3",
            "dtuser4",
            "dtuser5",
            "dtinvoice",
            "sinvno",
            "sbatchname",
            "iuse",
            "dtdue",
            "sassignedto",
            "iapprovalstate",
            "simportnotes",
            "hlocation",
            "scallcenter",
            "biscommwo",
            "sguid",
            "sreason",
            "sexpensetype",
            "dtonhold",
            "dtweb",
            "dtrequestreassignment",
            "dtuser6",
            "dtuser7",
            "dtuser8",
            "dtuser9",
            "dtuser10",
            "hjob",
            "hcommonarea",
            "hpayrcd",
            "bextdescript",
            "ifollowup",
            "hdisplaytype",
            "btax",
            "bpayables",
            "bcharges",
            "bpayfromchg",
            "bprinted",
            "dcommpercent",
            "dnottoexceed",
            "bdontschedule",
            "hbuilding",
            "hrooms",
            "htrancurrency",
            "dexchrate",
            "dpaytrantaxtotal",
            "hfunding",
            "hoccupant",
            "stechnotes"
          ],
          "cols_to_keep": [

          ],
          "fill_nas": {

          },
          "renaming_cols": {
          },
          "column_formats": {
              "character": [
                "sbriefdesc",
                "scategory",
                "ssubcat",
                "sstatus",
                "spriority",
                "sprobdescnotes",
                "saccessnotes",
                "sresolution",
                "sorigin",
                "stechnotes"
              ],
              "numeric": [
                "dpaytrantotal",
                "dchgtrantotal",
                "dchgtrantaxtotal"
              ],
              "id": [
                "hmy",
                "hproperty",
                "hunit",
                "htenant",
                "hfloor"
              ]
          }
      }    

  },
  "model_params": {
    "coords_dubai": {
      "lat": 25.276987,
      "lon":  55.296249
    },
    "n_months_target": 5,
    "min_train_date": "2018-06-01",
    "max_months_for_training": 12,
    "n_months_to_end_for_predicting": 3,
    "target_col": "target_binary",
    "model_algorithm": "RandomForestClassifier",
    "model_params": {"bootstrap": True, "n_estimators": 500, "min_samples_leaf": 50, "max_depth": 4, "random_state": 1991},
    "model_performance_excel_name": "model_performance_decile",
    "leads_df_excel_name": "leads"
  }
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
